# %% [markdown]
# # Exploring and loading data from a STAC catalogue

# %%
# !pip install hdstats
# Out:
# Collecting hdstats
#   Using cached hdstats-0.2.1.tar.gz (543 kB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\thana\.conda\envs\odc\lib\site-packages (from hdstats) (1.26.4)
# Requirement already satisfied: scipy in c:\users\thana\.conda\envs\odc\lib\site-packages (from hdstats) (1.14.0)
# Building wheels for collected packages: hdstats
#   Building wheel for hdstats (pyproject.toml): started
#   Building wheel for hdstats (pyproject.toml): finished with status 'done'
#   Created wheel for hdstats: filename=hdstats-0.2.1-cp312-cp312-win_amd64.whl size=951791 sha256=b9344974ec56344063170f18b9374405768ad8ecc4f223024c7864fd0d3b1f4d
#   Stored in directory: c:\users\thana\appdata\local\pip\cache\wheels\5b\78\a5\2cea2698e7eb19ef456500bd52ff67cf36daa40e61c359ae4b
# Successfully built hdstats
# Installing collected packages: hdstats
# Successfully installed hdstats-0.2.1

# %% [markdown]
# **Keywords** : `data used; sentinel-2`, `data search; STAC`, `platform; Amazon`

# %% [markdown]
# ## The Idea

# %% [markdown]
# The use of the SpatioTemporal Asset Catalog (STAC) to access data from public buckets like AWS, instead of downloading them, offers several key advantages that are critical for efficient data management and usage in geospatial and environmental research. First and foremost, STAC provides a standardized way to search and discover geospatial data stored across different cloud environments. This standardization significantly reduces the complexity and development time required for scientists and developers to interact with vast amounts of Earth Observation data.
#
# By utilizing STAC to access data directly from cloud services like AWS, users can leverage powerful cloud-based tools for processing and analyzing data on-the-fly without the need for extensive local storage or computing resources. This approach not only minimizes data redundancy—by eliminating the need to download large datasets—but also enhances scalability and flexibility in data handling. Researchers can quickly execute queries across large datasets, apply algorithms, and generate insights directly in the cloud, which accelerates the pace of innovation and application in fields such as climate analysis, urban planning, and disaster response.
#
# Moreover, accessing data via STAC from cloud platforms facilitates more dynamic and real-time data analysis. It allows users to integrate the latest data updates automatically and maintain the continuity and accuracy of their analyses. Overall, STAC’s role in connecting users with cloud-hosted public data resources fundamentally shifts the landscape of geospatial data utilization, making it more accessible, cost-effective, and aligned with the needs of a data-driven world.
#
# This notebook showcases:
# 1. How can we find public collections using pystac library
# 2. How can we search items inside a catalogue
# 3. How can we query metadata
# 4. How can we load directly data into a data cube using open data cube tools
#
# ***

# %% [markdown]
# ### Required Libraries

# %%
import pyproj
import pystac_client
from shapely.geometry import box
from shapely.ops import transform
import odc.stac
from odc.geo.geobox import GeoBox

# %% [markdown]
# ## Exploring Amazon's STAC catalogue

# %% [markdown]
# ### Find Collections

# %%
STAC_URL = "https://earth-search.aws.element84.com/v0"

client = pystac_client.Client.open(STAC_URL)
collections = client.get_collections()
for collection in collections:
    print(collection)
# Out:
# C:\Users\thana\.conda\envs\odc\Lib\site-packages\pystac_client\client.py:190: NoConformsTo: Server does not advertise any conformance classes.
#   warnings.warn(NoConformsTo())
# C:\Users\thana\.conda\envs\odc\Lib\site-packages\pystac_client\client.py:440: FallbackToPystac: Falling back to pystac. This might be slow.
#   self._warn_about_fallback("COLLECTIONS", "FEATURES")
# <CollectionClient id=sentinel-s2-l2a>
# <CollectionClient id=sentinel-s2-l1c>
# <CollectionClient id=sentinel-s2-l2a-cogs>
# <CollectionClient id=landsat-8-l1-c1>

# %% [markdown]
# ### Explore a Catalogue

# %%
# v0 collection
STAC_COLLECTION = "sentinel-s2-l2a-cogs"
# v1 collection
# STAC_COLLECTION = "sentinel-2-l2a"
catalog = pystac_client.Client.open(STAC_URL)
catalog.add_conforms_to("ITEM_SEARCH")
catalog.add_conforms_to("QUERY")
catalog
# Out:
# <Client id=earth-search>

# %% [markdown]
# ### Explore items inside a catalogue

# %%
# Get generator of all items in catalog
items = catalog.get_all_items()
item = next(items)
item
# Out:
# <Item id=S2B_15MWT_20230506_0_L2A>

# %% [markdown]
# ### Contrust a request - query to the catalogue
# Items in STAC catalog have much more metadata (in addition to location) that you can query and only return results that match your query parameters.
#
# First we need to set up some analysis parameters that will be used to search for metadata.
# This includes `product`, which is the same product name used to load data directly using `dc.load`. In this example we'll choose a small area over Athens.

# %%
# Parameters that are included in the query

# some spatial projection information
CRS_STRING = "9705"
EPSG = pyproj.CRS.from_string(CRS_STRING).to_epsg()

# Area of Interest
aoi = (23.906250,38.000356,24.004786,38.062149)
aoi_box = box(*aoi)

# Bands
BANDS = ["B04", "B03", "B02"]

# Time range
START_DATE = "2018-07-01"
END_DATE = "2018-08-10"

# STAC items store bounding box info in epsg:4326
STAC_CRS_STRING = "epsg:4326"
transformer_4326 = pyproj.Transformer.from_crs(
    crs_from=EPSG,
    crs_to=STAC_CRS_STRING,
    always_xy=True,
)
bbox_4326 = transform(transformer_4326.transform, aoi_box).bounds
bbox_4326
# Out:
# (23.90625, 38.000356, 24.004786, 38.062149)

# %%
# !pip install hdstats==0.2.1
# Out:
# Collecting hdstats==0.2.1
#   Using cached hdstats-0.2.1.tar.gz (543 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\thana\.conda\envs\odc\lib\site-packages (from hdstats==0.2.1) (1.26.4)
# Requirement already satisfied: scipy in c:\users\thana\.conda\envs\odc\lib\site-packages (from hdstats==0.2.1) (1.14.0)
# Building wheels for collected packages: hdstats
#   Building wheel for hdstats (pyproject.toml): started
#   Building wheel for hdstats (pyproject.toml): finished with status 'error'
# Failed to build hdstats
#   error: subprocess-exited-with-error
#
#   Building wheel for hdstats (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [39 lines of output]
#   {'include_dirs': ['C:\\Users\\thana\\AppData\\Local\\Temp\\pip-build-env-df7kgdql\\overlay\\Lib\\site-packages\\numpy\\_core\\include'], 'extra_compile_args': ['-fopenmp'], 'extra_link_args': ['-fopenmp'], 'define_macros': []}
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-312
#   creating build\lib.win-amd64-cpython-312\hdstats
#   copying hdstats\tsslow.py -> build\lib.win-amd64-cpython-312\hdstats
#   copying hdstats\utils.py -> build\lib.win-amd64-cpython-312\hdstats
#   copying hdstats\__init__.py -> build\lib.win-amd64-cpython-312\hdstats
#   running egg_info
#   writing hdstats.egg-info\PKG-INFO
#   writing dependency_links to hdstats.egg-info\dependency_links.txt
#   writing requirements to hdstats.egg-info\requires.txt
#   writing top-level names to hdstats.egg-info\top_level.txt
#   reading manifest file 'hdstats.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.rst' anywhere in distribution
#   warning: no files found matching '*.pxd' anywhere in distribution
#   warning: no files found matching '*.h' anywhere in distribution
#   no previously-included directories found matching '.eggs'
#   no previously-included directories found matching 'tests'
#   no previously-included directories found matching 'data'
#   no previously-included directories found matching 'docs'
#   no previously-included directories found matching '.vscode'
#   writing manifest file 'hdstats.egg-info\SOURCES.txt'
#   copying hdstats\dtw.c -> build\lib.win-amd64-cpython-312\hdstats
#   copying hdstats\dtw.pyx -> build\lib.win-amd64-cpython-312\hdstats
#   copying hdstats\geomad.c -> build\lib.win-amd64-cpython-312\hdstats
#   copying hdstats\geomad.pyx -> build\lib.win-amd64-cpython-312\hdstats
#   copying hdstats\geomedian.c -> build\lib.win-amd64-cpython-312\hdstats
#   copying hdstats\geomedian.pyx -> build\lib.win-amd64-cpython-312\hdstats
#   copying hdstats\ts.c -> build\lib.win-amd64-cpython-312\hdstats
#   copying hdstats\ts.pyx -> build\lib.win-amd64-cpython-312\hdstats
#   running build_ext
#   Compiling hdstats/geomedian.pyx because it changed.
#   [1/1] Cythonizing hdstats/geomedian.pyx
#   building 'hdstats.geomedian' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for hdstats
# ERROR: Could not build wheels for hdstats, which is required to install pyproject.toml-based projects

# %%
stac_items = catalog.search(
    collections=[STAC_COLLECTION],
    bbox=bbox_4326,
    datetime=[START_DATE, END_DATE],
    query={"eo:cloud_cover": {"lt": 10}}
)

# Deprecated:
# feature_collection = stac_items.get_all_items_as_dict()

feature_collection = stac_items.item_collection_as_dict()
feature_collection
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'stac_version': '1.0.0-beta.2',
#    'assets': {'overview': {'proj:shape': [343, 343],
#      'proj:transform': [320, 0, 199980, 0, -320, 4300020, 0, 0, 1],
#      'roles': ['overview'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'},
#       {'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'},
#       {'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/L2A_PVI.tif',
#      'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'thumbnail': {'roles': ['thumbnail'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/35/S/KC/2018/8/9/0/preview.jpg',
#      'title': 'Thumbnail',
#      'type': 'image/png'},
#     'metadata': {'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/35/S/KC/2018/8/9/0/metadata.xml',
#      'title': 'Original XML metadata',
#      'type': 'application/xml'},
#     'B11': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.143,
#        'center_wavelength': 1.6137,
#        'name': 'B11',
#        'common_name': 'swir16'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B11.tif',
#      'title': 'Band 11 (swir16)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B01': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 199980, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.027,
#        'center_wavelength': 0.4439,
#        'name': 'B01',
#        'common_name': 'coastal'}],
#      'gsd': 60,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B01.tif',
#      'title': 'Band 1 (coastal)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B12': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.242,
#        'center_wavelength': 2.22024,
#        'name': 'B12',
#        'common_name': 'swir22'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B12.tif',
#      'title': 'Band 12 (swir22)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B02': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B02.tif',
#      'title': 'Band 2 (blue)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B03': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B03.tif',
#      'title': 'Band 3 (green)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B04': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B04.tif',
#      'title': 'Band 4 (red)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'AOT': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 199980, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/AOT.tif',
#      'title': 'Aerosol Optical Thickness (AOT)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B05': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.019,
#        'center_wavelength': 0.7039,
#        'name': 'B05'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B05.tif',
#      'title': 'Band 5',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B06': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.018,
#        'center_wavelength': 0.7402,
#        'name': 'B06'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B06.tif',
#      'title': 'Band 6',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B07': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.028,
#        'center_wavelength': 0.7825,
#        'name': 'B07'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B07.tif',
#      'title': 'Band 7',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B08': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.145,
#        'center_wavelength': 0.8351,
#        'name': 'B08',
#        'common_name': 'nir'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B08.tif',
#      'title': 'Band 8 (nir)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B8A': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.033,
#        'center_wavelength': 0.8648,
#        'name': 'B8A'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B8A.tif',
#      'title': 'Band 8A',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B09': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 199980, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.026,
#        'center_wavelength': 0.945,
#        'name': 'B09'}],
#      'gsd': 60,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/B09.tif',
#      'title': 'Band 9',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'WVP': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/WVP.tif',
#      'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'visual': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['overview'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'},
#       {'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'},
#       {'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/TCI.tif',
#      'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'SCL': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/SCL.tif',
#      'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'info': {'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/35/S/KC/2018/8/9/0/tileInfo.json',
#      'title': 'Original JSON metadata',
#      'type': 'application/json'}},
#    'bbox': [23.545508965475886,
#     37.81011723197939,
#     24.838236184888004,
#     38.82843053932372],
#    'properties.sentinel:boa_offset_applied': False,
#    'geometry': {'coordinates': [[[23.592096265061393, 37.81011723197939],
#       [23.545508965475886, 38.79788599225959],
#       [24.80864150755705, 38.82843053932372],
#       [24.838236184888004, 37.83960429207432],
#       [23.592096265061393, 37.81011723197939]]],
#     'type': 'Polygon'},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_35SKC_20180809_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2A_35SKC_20180809_0_L2A/S2A_35SKC_20180809_0_L2A.json',
#      'type': 'application/json'},
#     {'rel': 'derived_from',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a/items/S2A_35SKC_20180809_0_L2A',
#      'title': 'Source STAC Item',
#      'type': 'application/json'},
#     {'rel': 'parent',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'collection',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'root', 'href': 'https://earth-search.aws.element84.com/v0/'}],
#    'id': 'S2A_35SKC_20180809_0_L2A',
#    'collection': 'sentinel-s2-l2a-cogs',
#    'type': 'Feature',
#    'stac_extensions': ['eo', 'view', 'proj'],
#    'properties': {'created': '2020-09-08T10:16:06.367Z',
#     'sentinel:product_id': 'S2A_MSIL2A_20180809T090551_N0208_R050_T35SKC_20180809T122252',
#     'sentinel:sequence': '0',
#     'view:off_nadir': 0,
#     'sentinel:valid_cloud_cover': True,
#     'platform': 'sentinel-2a',
#     'sentinel:utm_zone': 35,
#     'proj:epsg': 32635,
#     'sentinel:grid_square': 'KC',
#     'datetime': '2018-08-09T09:08:43Z',
#     'instruments': ['msi'],
#     'constellation': 'sentinel-2',
#     'eo:cloud_cover': 4.98,
#     'gsd': 10,
#     'sentinel:latitude_band': 'S',
#     'data_coverage': 100,
#     'updated': '2020-09-08T10:16:06.367Z',
#     'sentinel:data_coverage': 100}},
#   {'type': 'Feature',
#    'stac_version': '1.0.0-beta.2',
#    'stac_extensions': ['eo', 'view', 'proj'],
#    'id': 'S2A_34SGH_20180809_0_L2A',
#    'bbox': [23.272375824889362,
#     37.80686636747335,
#     24.566440855049226,
#     38.82627247685841],
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[24.5183513286846, 37.80686636747335],
#       [23.272375824889362, 37.8375209720972],
#       [23.303481623796433, 38.82627247685841],
#       [24.566440855049226, 38.79451859668191],
#       [24.5183513286846, 37.80686636747335]]]},
#    'properties': {'datetime': '2018-08-09T09:08:43Z',
#     'platform': 'sentinel-2a',
#     'constellation': 'sentinel-2',
#     'instruments': ['msi'],
#     'gsd': 10,
#     'view:off_nadir': 0,
#     'proj:epsg': 32634,
#     'sentinel:utm_zone': 34,
#     'sentinel:latitude_band': 'S',
#     'sentinel:grid_square': 'GH',
#     'sentinel:sequence': '0',
#     'sentinel:product_id': 'S2A_MSIL2A_20180809T090551_N0208_R050_T34SGH_20180809T122252',
#     'sentinel:data_coverage': 100,
#     'eo:cloud_cover': 4.24,
#     'sentinel:valid_cloud_cover': True,
#     'created': '2020-09-30T20:58:10.495Z',
#     'updated': '2020-09-30T20:58:10.495Z'},
#    'collection': 'sentinel-s2-l2a-cogs',
#    'assets': {'thumbnail': {'title': 'Thumbnail',
#      'type': 'image/png',
#      'roles': ['thumbnail'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/34/S/GH/2018/8/9/0/preview.jpg'},
#     'overview': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/L2A_PVI.tif',
#      'proj:shape': [343, 343],
#      'proj:transform': [320, 0, 699960, 0, -320, 4300020, 0, 0, 1]},
#     'info': {'title': 'Original JSON metadata',
#      'type': 'application/json',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/34/S/GH/2018/8/9/0/tileInfo.json'},
#     'metadata': {'title': 'Original XML metadata',
#      'type': 'application/xml',
#      'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/34/S/GH/2018/8/9/0/metadata.xml'},
#     'visual': {'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['overview'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038},
#       {'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045},
#       {'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/TCI.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1]},
#     'B01': {'title': 'Band 1 (coastal)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B01',
#        'common_name': 'coastal',
#        'center_wavelength': 0.4439,
#        'full_width_half_max': 0.027}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B01.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 699960, 0, -60, 4300020, 0, 0, 1]},
#     'B02': {'title': 'Band 2 (blue)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B02',
#        'common_name': 'blue',
#        'center_wavelength': 0.4966,
#        'full_width_half_max': 0.098}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B02.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1]},
#     'B03': {'title': 'Band 3 (green)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B03',
#        'common_name': 'green',
#        'center_wavelength': 0.56,
#        'full_width_half_max': 0.045}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B03.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1]},
#     'B04': {'title': 'Band 4 (red)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B04',
#        'common_name': 'red',
#        'center_wavelength': 0.6645,
#        'full_width_half_max': 0.038}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B04.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1]},
#     'B05': {'title': 'Band 5',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B05',
#        'center_wavelength': 0.7039,
#        'full_width_half_max': 0.019}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B05.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1]},
#     'B06': {'title': 'Band 6',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B06',
#        'center_wavelength': 0.7402,
#        'full_width_half_max': 0.018}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B06.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1]},
#     'B07': {'title': 'Band 7',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B07',
#        'center_wavelength': 0.7825,
#        'full_width_half_max': 0.028}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B07.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1]},
#     'B08': {'title': 'Band 8 (nir)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 10,
#      'eo:bands': [{'name': 'B08',
#        'common_name': 'nir',
#        'center_wavelength': 0.8351,
#        'full_width_half_max': 0.145}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B08.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1]},
#     'B8A': {'title': 'Band 8A',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B8A',
#        'center_wavelength': 0.8648,
#        'full_width_half_max': 0.033}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B8A.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1]},
#     'B09': {'title': 'Band 9',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 60,
#      'eo:bands': [{'name': 'B09',
#        'center_wavelength': 0.945,
#        'full_width_half_max': 0.026}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B09.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 699960, 0, -60, 4300020, 0, 0, 1]},
#     'B11': {'title': 'Band 11 (swir16)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B11',
#        'common_name': 'swir16',
#        'center_wavelength': 1.6137,
#        'full_width_half_max': 0.143}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B11.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1]},
#     'B12': {'title': 'Band 12 (swir22)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'gsd': 20,
#      'eo:bands': [{'name': 'B12',
#        'common_name': 'swir22',
#        'center_wavelength': 2.22024,
#        'full_width_half_max': 0.242}],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/B12.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1]},
#     'AOT': {'title': 'Aerosol Optical Thickness (AOT)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/AOT.tif',
#      'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 699960, 0, -60, 4300020, 0, 0, 1]},
#     'WVP': {'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/WVP.tif',
#      'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1]},
#     'SCL': {'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized',
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/SCL.tif',
#      'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1]}},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2A_34SGH_20180809_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2A_34SGH_20180809_0_L2A/S2A_34SGH_20180809_0_L2A.json',
#      'type': 'application/json'},
#     {'title': 'Source STAC Item',
#      'rel': 'derived_from',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a/items/S2A_34SGH_20180809_0_L2A',
#      'type': 'application/json'},
#     {'rel': 'parent',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'collection',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'root', 'href': 'https://earth-search.aws.element84.com/v0/'}]},
#   {'stac_version': '1.0.0-beta.2',
#    'assets': {'overview': {'proj:shape': [343, 343],
#      'proj:transform': [320, 0, 699960, 0, -320, 4300020, 0, 0, 1],
#      'roles': ['overview'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'},
#       {'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'},
#       {'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/L2A_PVI.tif',
#      'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'thumbnail': {'roles': ['thumbnail'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/34/S/GH/2018/8/4/0/preview.jpg',
#      'title': 'Thumbnail',
#      'type': 'image/png'},
#     'metadata': {'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/34/S/GH/2018/8/4/0/metadata.xml',
#      'title': 'Original XML metadata',
#      'type': 'application/xml'},
#     'B11': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.143,
#        'center_wavelength': 1.6137,
#        'name': 'B11',
#        'common_name': 'swir16'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B11.tif',
#      'title': 'Band 11 (swir16)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B01': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 699960, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.027,
#        'center_wavelength': 0.4439,
#        'name': 'B01',
#        'common_name': 'coastal'}],
#      'gsd': 60,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B01.tif',
#      'title': 'Band 1 (coastal)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B12': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.242,
#        'center_wavelength': 2.22024,
#        'name': 'B12',
#        'common_name': 'swir22'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B12.tif',
#      'title': 'Band 12 (swir22)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B02': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B02.tif',
#      'title': 'Band 2 (blue)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B03': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B03.tif',
#      'title': 'Band 3 (green)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B04': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B04.tif',
#      'title': 'Band 4 (red)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'AOT': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 699960, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/AOT.tif',
#      'title': 'Aerosol Optical Thickness (AOT)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B05': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.019,
#        'center_wavelength': 0.7039,
#        'name': 'B05'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B05.tif',
#      'title': 'Band 5',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B06': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.018,
#        'center_wavelength': 0.7402,
#        'name': 'B06'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B06.tif',
#      'title': 'Band 6',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B07': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.028,
#        'center_wavelength': 0.7825,
#        'name': 'B07'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B07.tif',
#      'title': 'Band 7',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B08': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.145,
#        'center_wavelength': 0.8351,
#        'name': 'B08',
#        'common_name': 'nir'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B08.tif',
#      'title': 'Band 8 (nir)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B8A': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.033,
#        'center_wavelength': 0.8648,
#        'name': 'B8A'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B8A.tif',
#      'title': 'Band 8A',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B09': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 699960, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.026,
#        'center_wavelength': 0.945,
#        'name': 'B09'}],
#      'gsd': 60,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/B09.tif',
#      'title': 'Band 9',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'WVP': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/WVP.tif',
#      'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'visual': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['overview'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'},
#       {'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'},
#       {'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/TCI.tif',
#      'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'SCL': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/SCL.tif',
#      'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'info': {'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/34/S/GH/2018/8/4/0/tileInfo.json',
#      'title': 'Original JSON metadata',
#      'type': 'application/json'}},
#    'bbox': [23.272375824889362,
#     37.80686636747335,
#     24.566440855049226,
#     38.82627247685841],
#    'properties.sentinel:boa_offset_applied': False,
#    'geometry': {'coordinates': [[[24.5183513286846, 37.80686636747335],
#       [23.272375824889362, 37.8375209720972],
#       [23.303481623796433, 38.82627247685841],
#       [24.566440855049226, 38.79451859668191],
#       [24.5183513286846, 37.80686636747335]]],
#     'type': 'Polygon'},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_34SGH_20180804_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/8/S2B_34SGH_20180804_0_L2A/S2B_34SGH_20180804_0_L2A.json',
#      'type': 'application/json'},
#     {'rel': 'derived_from',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a/items/S2B_34SGH_20180804_0_L2A',
#      'title': 'Source STAC Item',
#      'type': 'application/json'},
#     {'rel': 'parent',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'collection',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'root', 'href': 'https://earth-search.aws.element84.com/v0/'}],
#    'id': 'S2B_34SGH_20180804_0_L2A',
#    'collection': 'sentinel-s2-l2a-cogs',
#    'type': 'Feature',
#    'stac_extensions': ['eo', 'view', 'proj'],
#    'properties': {'created': '2020-09-06T09:42:17.858Z',
#     'sentinel:product_id': 'S2B_MSIL2A_20180804T090549_N0208_R050_T34SGH_20180804T142040',
#     'sentinel:sequence': '0',
#     'view:off_nadir': 0,
#     'sentinel:valid_cloud_cover': True,
#     'platform': 'sentinel-2b',
#     'sentinel:utm_zone': 34,
#     'proj:epsg': 32634,
#     'sentinel:grid_square': 'GH',
#     'datetime': '2018-08-04T09:10:49Z',
#     'instruments': ['msi'],
#     'constellation': 'sentinel-2',
#     'eo:cloud_cover': 4.4,
#     'gsd': 10,
#     'sentinel:latitude_band': 'S',
#     'sentinel:data_coverage': 100,
#     'updated': '2020-09-06T09:42:17.858Z'}},
#   {'stac_version': '1.0.0-beta.2',
#    'assets': {'overview': {'proj:shape': [343, 343],
#      'proj:transform': [320, 0, 199980, 0, -320, 4300020, 0, 0, 1],
#      'roles': ['overview'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'},
#       {'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'},
#       {'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/L2A_PVI.tif',
#      'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'thumbnail': {'roles': ['thumbnail'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/35/S/KC/2018/8/4/0/preview.jpg',
#      'title': 'Thumbnail',
#      'type': 'image/png'},
#     'metadata': {'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/35/S/KC/2018/8/4/0/metadata.xml',
#      'title': 'Original XML metadata',
#      'type': 'application/xml'},
#     'B11': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.143,
#        'center_wavelength': 1.6137,
#        'name': 'B11',
#        'common_name': 'swir16'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B11.tif',
#      'title': 'Band 11 (swir16)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B01': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 199980, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.027,
#        'center_wavelength': 0.4439,
#        'name': 'B01',
#        'common_name': 'coastal'}],
#      'gsd': 60,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B01.tif',
#      'title': 'Band 1 (coastal)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B12': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.242,
#        'center_wavelength': 2.22024,
#        'name': 'B12',
#        'common_name': 'swir22'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B12.tif',
#      'title': 'Band 12 (swir22)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B02': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B02.tif',
#      'title': 'Band 2 (blue)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B03': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B03.tif',
#      'title': 'Band 3 (green)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B04': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B04.tif',
#      'title': 'Band 4 (red)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'AOT': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 199980, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/AOT.tif',
#      'title': 'Aerosol Optical Thickness (AOT)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B05': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.019,
#        'center_wavelength': 0.7039,
#        'name': 'B05'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B05.tif',
#      'title': 'Band 5',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B06': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.018,
#        'center_wavelength': 0.7402,
#        'name': 'B06'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B06.tif',
#      'title': 'Band 6',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B07': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.028,
#        'center_wavelength': 0.7825,
#        'name': 'B07'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B07.tif',
#      'title': 'Band 7',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B08': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.145,
#        'center_wavelength': 0.8351,
#        'name': 'B08',
#        'common_name': 'nir'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B08.tif',
#      'title': 'Band 8 (nir)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B8A': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.033,
#        'center_wavelength': 0.8648,
#        'name': 'B8A'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B8A.tif',
#      'title': 'Band 8A',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B09': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 199980, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.026,
#        'center_wavelength': 0.945,
#        'name': 'B09'}],
#      'gsd': 60,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/B09.tif',
#      'title': 'Band 9',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'WVP': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/WVP.tif',
#      'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'visual': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['overview'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'},
#       {'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'},
#       {'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/TCI.tif',
#      'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'SCL': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/SCL.tif',
#      'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'info': {'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/35/S/KC/2018/8/4/0/tileInfo.json',
#      'title': 'Original JSON metadata',
#      'type': 'application/json'}},
#    'bbox': [23.545508965475886,
#     37.81011723197939,
#     24.838236184888004,
#     38.82843053932372],
#    'properties.sentinel:boa_offset_applied': False,
#    'geometry': {'coordinates': [[[23.592096265061393, 37.81011723197939],
#       [23.545508965475886, 38.79788599225959],
#       [24.80864150755705, 38.82843053932372],
#       [24.838236184888004, 37.83960429207432],
#       [23.592096265061393, 37.81011723197939]]],
#     'type': 'Polygon'},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_35SKC_20180804_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/8/S2B_35SKC_20180804_0_L2A/S2B_35SKC_20180804_0_L2A.json',
#      'type': 'application/json'},
#     {'rel': 'derived_from',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a/items/S2B_35SKC_20180804_0_L2A',
#      'title': 'Source STAC Item',
#      'type': 'application/json'},
#     {'rel': 'parent',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'collection',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'root', 'href': 'https://earth-search.aws.element84.com/v0/'}],
#    'id': 'S2B_35SKC_20180804_0_L2A',
#    'collection': 'sentinel-s2-l2a-cogs',
#    'type': 'Feature',
#    'stac_extensions': ['eo', 'view', 'proj'],
#    'properties': {'created': '2020-09-08T14:38:26.230Z',
#     'sentinel:product_id': 'S2B_MSIL2A_20180804T090549_N0208_R050_T35SKC_20180804T142040',
#     'sentinel:sequence': '0',
#     'view:off_nadir': 0,
#     'sentinel:valid_cloud_cover': True,
#     'platform': 'sentinel-2b',
#     'sentinel:utm_zone': 35,
#     'proj:epsg': 32635,
#     'sentinel:grid_square': 'KC',
#     'datetime': '2018-08-04T09:10:49Z',
#     'instruments': ['msi'],
#     'constellation': 'sentinel-2',
#     'eo:cloud_cover': 3.64,
#     'gsd': 10,
#     'sentinel:latitude_band': 'S',
#     'data_coverage': 100,
#     'updated': '2020-09-08T14:38:26.230Z',
#     'sentinel:data_coverage': 100}},
#   {'stac_version': '1.0.0-beta.2',
#    'assets': {'overview': {'proj:shape': [343, 343],
#      'proj:transform': [320, 0, 199980, 0, -320, 4300020, 0, 0, 1],
#      'roles': ['overview'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'},
#       {'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'},
#       {'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180725_0_L2A/L2A_PVI.tif',
#      'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'thumbnail': {'roles': ['thumbnail'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/35/S/KC/2018/7/25/0/preview.jpg',
#      'title': 'Thumbnail',
#      'type': 'image/png'},
#     'metadata': {'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/35/S/KC/2018/7/25/0/metadata.xml',
#      'title': 'Original XML metadata',
#      'type': 'application/xml'},
#     'B11': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.143,
#        'center_wavelength': 1.6137,
#        'name': 'B11',
#        'common_name': 'swir16'}],
# ...
#      'proj:transform': [60, 0, 699960, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.026,
#        'center_wavelength': 0.945,
#        'name': 'B09'}],
#      'gsd': 60,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/7/S2B_34SGH_20180705_0_L2A/B09.tif',
#      'title': 'Band 9',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'WVP': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/7/S2B_34SGH_20180705_0_L2A/WVP.tif',
#      'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'visual': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 699960, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['overview'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'},
#       {'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'},
#       {'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/7/S2B_34SGH_20180705_0_L2A/TCI.tif',
#      'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'SCL': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 699960, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/7/S2B_34SGH_20180705_0_L2A/SCL.tif',
#      'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'info': {'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/34/S/GH/2018/7/5/0/tileInfo.json',
#      'title': 'Original JSON metadata',
#      'type': 'application/json'}},
#    'bbox': [23.272375824889362,
#     37.80686636747335,
#     24.566440855049226,
#     38.82627247685841],
#    'properties.sentinel:boa_offset_applied': False,
#    'geometry': {'coordinates': [[[24.5183513286846, 37.80686636747335],
#       [23.272375824889362, 37.8375209720972],
#       [23.303481623796433, 38.82627247685841],
#       [24.566440855049226, 38.79451859668191],
#       [24.5183513286846, 37.80686636747335]]],
#     'type': 'Polygon'},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_34SGH_20180705_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/34/S/GH/2018/7/S2B_34SGH_20180705_0_L2A/S2B_34SGH_20180705_0_L2A.json',
#      'type': 'application/json'},
#     {'rel': 'derived_from',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a/items/S2B_34SGH_20180705_0_L2A',
#      'title': 'Source STAC Item',
#      'type': 'application/json'},
#     {'rel': 'parent',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'collection',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'root', 'href': 'https://earth-search.aws.element84.com/v0/'}],
#    'id': 'S2B_34SGH_20180705_0_L2A',
#    'collection': 'sentinel-s2-l2a-cogs',
#    'type': 'Feature',
#    'stac_extensions': ['eo', 'view', 'proj'],
#    'properties': {'created': '2020-09-06T09:04:47.772Z',
#     'sentinel:product_id': 'S2B_MSIL2A_20180705T091019_N0208_R050_T34SGH_20180705T133603',
#     'sentinel:sequence': '0',
#     'view:off_nadir': 0,
#     'sentinel:valid_cloud_cover': True,
#     'platform': 'sentinel-2b',
#     'sentinel:utm_zone': 34,
#     'proj:epsg': 32634,
#     'sentinel:grid_square': 'GH',
#     'datetime': '2018-07-05T09:17:02Z',
#     'instruments': ['msi'],
#     'constellation': 'sentinel-2',
#     'eo:cloud_cover': 0.2,
#     'gsd': 10,
#     'sentinel:latitude_band': 'S',
#     'data_coverage': 100,
#     'updated': '2020-09-06T09:04:47.772Z',
#     'sentinel:data_coverage': 100}},
#   {'stac_version': '1.0.0-beta.2',
#    'assets': {'overview': {'proj:shape': [343, 343],
#      'proj:transform': [320, 0, 199980, 0, -320, 4300020, 0, 0, 1],
#      'roles': ['overview'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'},
#       {'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'},
#       {'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/L2A_PVI.tif',
#      'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'thumbnail': {'roles': ['thumbnail'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/35/S/KC/2018/7/5/0/preview.jpg',
#      'title': 'Thumbnail',
#      'type': 'image/png'},
#     'metadata': {'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/35/S/KC/2018/7/5/0/metadata.xml',
#      'title': 'Original XML metadata',
#      'type': 'application/xml'},
#     'B11': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.143,
#        'center_wavelength': 1.6137,
#        'name': 'B11',
#        'common_name': 'swir16'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B11.tif',
#      'title': 'Band 11 (swir16)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B01': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 199980, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.027,
#        'center_wavelength': 0.4439,
#        'name': 'B01',
#        'common_name': 'coastal'}],
#      'gsd': 60,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B01.tif',
#      'title': 'Band 1 (coastal)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B12': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.242,
#        'center_wavelength': 2.22024,
#        'name': 'B12',
#        'common_name': 'swir22'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B12.tif',
#      'title': 'Band 12 (swir22)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B02': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B02.tif',
#      'title': 'Band 2 (blue)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B03': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B03.tif',
#      'title': 'Band 3 (green)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B04': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B04.tif',
#      'title': 'Band 4 (red)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'AOT': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 199980, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/AOT.tif',
#      'title': 'Aerosol Optical Thickness (AOT)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B05': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.019,
#        'center_wavelength': 0.7039,
#        'name': 'B05'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B05.tif',
#      'title': 'Band 5',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B06': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.018,
#        'center_wavelength': 0.7402,
#        'name': 'B06'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B06.tif',
#      'title': 'Band 6',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B07': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.028,
#        'center_wavelength': 0.7825,
#        'name': 'B07'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B07.tif',
#      'title': 'Band 7',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B08': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.145,
#        'center_wavelength': 0.8351,
#        'name': 'B08',
#        'common_name': 'nir'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B08.tif',
#      'title': 'Band 8 (nir)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B8A': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.033,
#        'center_wavelength': 0.8648,
#        'name': 'B8A'}],
#      'gsd': 20,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B8A.tif',
#      'title': 'Band 8A',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'B09': {'proj:shape': [1830, 1830],
#      'proj:transform': [60, 0, 199980, 0, -60, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'eo:bands': [{'full_width_half_max': 0.026,
#        'center_wavelength': 0.945,
#        'name': 'B09'}],
#      'gsd': 60,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/B09.tif',
#      'title': 'Band 9',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'WVP': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/WVP.tif',
#      'title': 'Water Vapour (WVP)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'visual': {'proj:shape': [10980, 10980],
#      'proj:transform': [10, 0, 199980, 0, -10, 4300020, 0, 0, 1],
#      'roles': ['overview'],
#      'eo:bands': [{'full_width_half_max': 0.038,
#        'center_wavelength': 0.6645,
#        'name': 'B04',
#        'common_name': 'red'},
#       {'full_width_half_max': 0.045,
#        'center_wavelength': 0.56,
#        'name': 'B03',
#        'common_name': 'green'},
#       {'full_width_half_max': 0.098,
#        'center_wavelength': 0.4966,
#        'name': 'B02',
#        'common_name': 'blue'}],
#      'gsd': 10,
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/TCI.tif',
#      'title': 'True color image',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'SCL': {'proj:shape': [5490, 5490],
#      'proj:transform': [20, 0, 199980, 0, -20, 4300020, 0, 0, 1],
#      'roles': ['data'],
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/SCL.tif',
#      'title': 'Scene Classification Map (SCL)',
#      'type': 'image/tiff; application=geotiff; profile=cloud-optimized'},
#     'info': {'roles': ['metadata'],
#      'href': 'https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/35/S/KC/2018/7/5/0/tileInfo.json',
#      'title': 'Original JSON metadata',
#      'type': 'application/json'}},
#    'bbox': [23.545508965475886,
#     37.81011723197939,
#     24.838236184888004,
#     38.82843053932372],
#    'properties.sentinel:boa_offset_applied': False,
#    'geometry': {'coordinates': [[[23.592096265061393, 37.81011723197939],
#       [23.545508965475886, 38.79788599225959],
#       [24.80864150755705, 38.82843053932372],
#       [24.838236184888004, 37.83960429207432],
#       [23.592096265061393, 37.81011723197939]]],
#     'type': 'Polygon'},
#    'links': [{'rel': 'self',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs/items/S2B_35SKC_20180705_0_L2A'},
#     {'rel': 'canonical',
#      'href': 'https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/35/S/KC/2018/7/S2B_35SKC_20180705_0_L2A/S2B_35SKC_20180705_0_L2A.json',
#      'type': 'application/json'},
#     {'rel': 'derived_from',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a/items/S2B_35SKC_20180705_0_L2A',
#      'title': 'Source STAC Item',
#      'type': 'application/json'},
#     {'rel': 'parent',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'collection',
#      'href': 'https://earth-search.aws.element84.com/v0/collections/sentinel-s2-l2a-cogs'},
#     {'rel': 'root', 'href': 'https://earth-search.aws.element84.com/v0/'}],
#    'id': 'S2B_35SKC_20180705_0_L2A',
#    'collection': 'sentinel-s2-l2a-cogs',
#    'type': 'Feature',
#    'stac_extensions': ['eo', 'view', 'proj'],
#    'properties': {'created': '2020-09-30T17:23:01.782Z',
#     'sentinel:product_id': 'S2B_MSIL2A_20180705T091019_N0208_R050_T35SKC_20180705T133603',
#     'sentinel:sequence': '0',
#     'view:off_nadir': 0,
#     'sentinel:valid_cloud_cover': True,
#     'platform': 'sentinel-2b',
#     'sentinel:utm_zone': 35,
#     'proj:epsg': 32635,
#     'sentinel:grid_square': 'KC',
#     'datetime': '2018-07-05T09:17:02Z',
#     'instruments': ['msi'],
#     'constellation': 'sentinel-2',
#     'eo:cloud_cover': 0.21,
#     'gsd': 10,
#     'sentinel:latitude_band': 'S',
#     'data_coverage': 100,
#     'updated': '2020-09-30T17:23:01.782Z',
#     'sentinel:data_coverage': 100}}]}

# %%
# Deprecated old version:
# assets = stac_items.get_all_items()[0].assets

assets = stac_items.item_collection()[0].assets

for key, asset in assets.items():
    print(f"{key}: {asset.title}")
# Out:
# overview: True color image
# thumbnail: Thumbnail
# metadata: Original XML metadata
# B11: Band 11 (swir16)
# B01: Band 1 (coastal)
# B12: Band 12 (swir22)
# B02: Band 2 (blue)
# B03: Band 3 (green)
# B04: Band 4 (red)
# AOT: Aerosol Optical Thickness (AOT)
# B05: Band 5
# B06: Band 6
# B07: Band 7
# B08: Band 8 (nir)
# B8A: Band 8A
# B09: Band 9
# WVP: Water Vapour (WVP)
# visual: True color image
# SCL: Scene Classification Map (SCL)
# info: Original JSON metadata

# %% [markdown]
# ## Load Data directly in an xarray using ODC stac component
#
# The code snippet below showcases how the ODC software, with its STAC component, can be adeptly utilized to manage and analyze satellite imagery data at varying resolutions. The snippet begins by defining `spatial resolutions`—approximately 10 meters—highlighting ODC's capability to handle data granularity based on specific research or operational requirements. The use of a `projection system` (EPSG:4326) for the coordinate reference system is typical for global datasets and ensures that data from various sources aligns correctly on a standard geographic grid.
#
# The instantiation of a `GeoBox` object with these parameters effectively sets up a spatial query box, which filters the data to the defined bounding box, thus optimizing data loading processes by eliminating unnecessary data outside of the interest area. This approach is particularly beneficial in cloud computing environments, where data transfer and processing times are critical cost factors.
#
# The `odc.stac.load` function call is pivotal, demonstrating how STAC items are loaded with specified assets (red, green, blue) and other parameters. The use of chunking enhances performance for large datasets, and specifying a geobox ensures that only the relevant spatial extent is loaded. Notably, the function filters for `specific bands`, and employs `bilinear resampling` to interpolate pixel values, enhancing the visual quality of the imagery.
#
# Lastly, grouping by `solar_day` is a clever use of the data's temporal dimension to mitigate the issue of duplicate observations due to satellite overlap. This functionality ensures that each dataset represents a unique snapshot in time, which is crucial for time-series analysis and change detection studies. Overall, this code is a succinct demonstration of how modern geospatial data workflows can be streamlined through the integration of ODC and STAC, facilitating efficient, scalable, and precise environmental monitoring and analysis.

# %%
# using Open Data Cube stac component
dx = 3/3600  # ~90m resolution
# dx = 10 / 111320 # ~10m res
epsg = 4326
geobox = GeoBox.from_bbox(aoi, crs=f"epsg:{epsg}", resolution=dx)

data = odc.stac.load(
    stac_items.items(),
    assets=["red", "green", "blue"],
    chunks={},
    geobox=geobox,
    bands=BANDS,
    resampling="bilinear",
    groupby="solar_day" # delete duplicates due to satellite overlap
)

# %%
data
# Out:
# <xarray.Dataset> Size: 644kB
# Dimensions:      (latitude: 75, longitude: 119, time: 6)
# Coordinates:
#   * latitude     (latitude) float64 600B 38.06 38.06 38.06 ... 38.0 38.0 38.0
#   * longitude    (longitude) float64 952B 23.91 23.91 23.91 ... 24.0 24.0 24.0
#     spatial_ref  int32 4B 4326
#   * time         (time) datetime64[ns] 48B 2018-07-05T09:17:02 ... 2018-08-09...
# Data variables:
#     B04          (time, latitude, longitude) float32 214kB dask.array<chunksize=(1, 75, 119), meta=np.ndarray>
#     B03          (time, latitude, longitude) float32 214kB dask.array<chunksize=(1, 75, 119), meta=np.ndarray>
#     B02          (time, latitude, longitude) float32 214kB dask.array<chunksize=(1, 75, 119), meta=np.ndarray>
