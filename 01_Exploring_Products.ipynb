# %%
import datacube
import pandas as pd
from odc.ui import DcViewer

# Set some configurations for displaying tables nicely
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.max_rows', None)

# %%
dc = datacube.Datacube(app="01_Existing_Products_and_measurements")
# Out:
# Application name is too long: Truncating to 26 chars
# NOTICE:  identifier "-Products-and-measurements agdc-1.8.19.dev13+g8b46c228.d20240621" will be truncated to "-Products-and-measurements agdc-1.8.19.dev13+g8b46c228.d2024062"

# %%
dc.list_products().columns
# Out:
# Index(['name', 'description', 'license', 'default_crs', 'default_resolution'], dtype='object')

# %%
products = dc.list_products()

display_columns = ["name",
                   "description",
                   "default_crs",
                   "default_resolution"]

products[display_columns].sort_index()
# Out:
#             name  \
# name
# s2_cogs  s2_cogs
#
#                                                                                                                         description  \
# name
# s2_cogs  Sentinel-2a and Sentinel-2b imagery, processed to Level 2A (Surface Reflectance) and converted to Cloud Optimized GeoTIFFs
#
#         default_crs default_resolution
# name
# s2_cogs   EPSG:3857      (-10.0, 10.0)

# %%
product = "s2_cogs"
measurements = dc.list_measurements()
measurements.loc[product]
# Out:
#             name   dtype units  nodata                            aliases  \
# measurement
# B01          B01  uint16     1       0    [band_01, B01, coastal_aerosol]
# B02          B02  uint16     1       0               [band_02, B02, blue]
# B03          B03  uint16     1       0              [band_03, B03, green]
# B04          B04  uint16     1       0                [band_04, B04, red]
# B05          B05  uint16     1       0         [band_05, B05, red_edge_1]
# B06          B06  uint16     1       0         [band_06, B06, red_edge_2]
# B07          B07  uint16     1       0         [band_07, B07, red_edge_3]
# B08          B08  uint16     1       0         [band_08, B08, nir, nir_1]
# B8A          B8A  uint16     1       0  [band_8a, B8A, nir_narrow, nir_2]
# B09          B09  uint16     1       0       [band_09, B09, water_vapour]
# B11          B11  uint16     1       0    [band_11, B11, swir_1, swir_16]
# B12          B12  uint16     1       0    [band_12, B12, swir_2, swir_22]
# SCL          SCL   uint8     1       0                    [mask, SCL, qa]
# tci          tci   uint8     1       0            [TCI, true_color_image]
#
#                                                                                                                                                                                                     flags_definition
# measurement
# B01                                                                                                                                                                                                              NaN
# B02                                                                                                                                                                                                              NaN
# B03                                                                                                                                                                                                              NaN
# B04                                                                                                                                                                                                              NaN
# B05                                                                                                                                                                                                              NaN
# B06                                                                                                                                                                                                              NaN
# B07                                                                                                                                                                                                              NaN
# B08                                                                                                                                                                                                              NaN
# B8A                                                                                                                                                                                                              NaN
# B09                                                                                                                                                                                                              NaN
# B11                                                                                                                                                                                                              NaN
# B12                                                                                                                                                                                                              NaN
# SCL          {'qa': {'bits': [0, 1, 2, 3, 4, 5, 6, 7], 'values': {'0': 'no data', '1': 'saturated or defective', '2': 'dark area pixels', '3': 'cloud shadows', '4': 'vegetation', '5': 'bare soils', '6': 'water...
# tci                                                                                                                                                                                                              NaN

# %%
# !jupyter nbextension enable --py --sys-prefix ipyleaflet
# Out:
# Traceback (most recent call last):
#   File "/usr/bin/jupyter-nbextension", line 33, in <module>
#     sys.exit(load_entry_point('notebook==6.4.12', 'console_scripts', 'jupyter-nbextension')())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/jupyter_core/application.py", line 282, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/usr/lib/python3/dist-packages/traitlets/config/application.py", line 982, in launch_instance
#     app.start()
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 972, in start
#     super().start()
#   File "/usr/lib/python3/dist-packages/jupyter_core/application.py", line 271, in start
#     self.subapp.start()
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 882, in start
#     self.toggle_nbextension_python(self.extra_args[0])
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 855, in toggle_nbextension_python
#     return toggle(module,
#            ^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 470, in enable_nbextension_python
#     return _set_nbextension_state_python(True, module, user, sys_prefix,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 368, in _set_nbextension_state_python
#     m, nbexts = _get_nbextension_metadata(module)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 1107, in _get_nbextension_metadata
#     m = import_item(module)
#         ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/traitlets/utils/importstring.py", line 38, in import_item
#     return __import__(parts[0])
#            ^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'ipyleaflet'

# %%
DcViewer(dc=dc, 
         time='2024',
         center=(0.565, 38.007),
         zoom=6)
# Out:
# VBox(children=(HBox(children=(Dropdown(layout=Layout(flex='0 1 auto', width='10em'), options=('s2_cogs',), val…

# %%
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: problems found:
#         - require?  X jupyter-js-widgets/extension
# Traceback (most recent call last):
#   File "/usr/bin/jupyter-nbextension", line 33, in <module>
#     sys.exit(load_entry_point('notebook==6.4.12', 'console_scripts', 'jupyter-nbextension')())
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/jupyter_core/application.py", line 282, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/usr/lib/python3/dist-packages/traitlets/config/application.py", line 982, in launch_instance
#     app.start()
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 972, in start
#     super().start()
#   File "/usr/lib/python3/dist-packages/jupyter_core/application.py", line 271, in start
#     self.subapp.start()
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 882, in start
#     self.toggle_nbextension_python(self.extra_args[0])
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 855, in toggle_nbextension_python
#     return toggle(module,
#            ^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 470, in enable_nbextension_python
#     return _set_nbextension_state_python(True, module, user, sys_prefix,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 368, in _set_nbextension_state_python
#     m, nbexts = _get_nbextension_metadata(module)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/notebook/nbextensions.py", line 1107, in _get_nbextension_metadata
#     m = import_item(module)
#         ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/traitlets/utils/importstring.py", line 38, in import_item
#     return __import__(parts[0])
#            ^^^^^^^^^^^^^^^^^^^^
# ModuleNotFoundError: No module named 'ipyleaflet'
